# %% [markdown]
# ### Sobre el conjunto de datos
#
# **Contexto**
# Una compañía ficticia de telecomunicaciones que ofrecía servicios de telefonía fija e Internet a 7043 clientes en California en el tercer trimestre.
#
# **Descripción de los datos**
# 7043 observaciones con 33 variables
#
# * **CustomerID**: Un ID único que identifica a cada cliente.
# * **Count**: Un valor usado en reportes/dashboards para sumar el número de clientes en un conjunto filtrado.
# * **Country**: País de residencia principal del cliente.
# * **State**: Estado de residencia principal del cliente.
# * **City**: Ciudad de residencia principal del cliente.
# * **Zip Code**: Código postal de residencia principal del cliente.
# * **Lat Long**: Latitud y longitud combinadas de la residencia principal del cliente.
# * **Latitude**: Latitud de la residencia principal del cliente.
# * **Longitude**: Longitud de la residencia principal del cliente.
# * **Gender**: Género del cliente: Masculino, Femenino.
# * **Senior Citizen**: Indica si el cliente tiene 65 años o más: Sí, No.
# * **Partner**: Indica si el cliente tiene pareja: Sí, No.
# * **Dependents**: Indica si el cliente vive con personas a cargo: Sí, No. Los dependientes pueden ser hijos, padres, abuelos, etc.
# * **Tenure Months**: Indica el número total de meses que el cliente ha estado con la compañía hasta el final del trimestre mencionado.
# * **Phone Service**: Indica si el cliente está suscrito al servicio de telefonía fija de la compañía: Sí, No.
# * **Multiple Lines**: Indica si el cliente está suscrito a múltiples líneas telefónicas con la compañía: Sí, No.
# * **Internet Service**: Indica si el cliente está suscrito al servicio de Internet de la compañía: No, DSL, Fibra Óptica, Cable.
# * **Online Security**: Indica si el cliente está suscrito a un servicio adicional de seguridad en línea ofrecido por la compañía: Sí, No.
# * **Online Backup**: Indica si el cliente está suscrito a un servicio adicional de respaldo en línea ofrecido por la compañía: Sí, No.
# * **Device Protection**: Indica si el cliente está suscrito a un plan adicional de protección de dispositivos para su equipo de Internet ofrecido por la compañía: Sí, No.
# * **Tech Support**: Indica si el cliente está suscrito a un plan adicional de soporte técnico con tiempos de espera reducidos ofrecido por la compañía: Sí, No.
# * **Streaming TV**: Indica si el cliente usa su servicio de Internet para ver televisión en streaming de un proveedor externo: Sí, No. La compañía no cobra tarifa adicional por este servicio.
# * **Streaming Movies**: Indica si el cliente usa su servicio de Internet para ver películas en streaming de un proveedor externo: Sí, No. La compañía no cobra tarifa adicional por este servicio.
# * **Contract**: Indica el tipo de contrato actual del cliente: Mes a mes, Un año, Dos años.
# * **Paperless Billing**: Indica si el cliente eligió facturación sin papel: Sí, No.
# * **Payment Method**: Indica cómo paga el cliente su factura: Domiciliación bancaria, Tarjeta de crédito, Cheque enviado por correo.
# * **Monthly Charge**: Indica el cargo mensual total actual del cliente por todos los servicios de la compañía.
# * **Total Charges**: Indica el cargo total del cliente, calculado hasta el final del trimestre mencionado.
# * **Churn Label**: Sí = el cliente dejó la compañía este trimestre. No = el cliente permaneció en la compañía. Relacionado directamente con *Churn Value*.
# * **Churn Value**: 1 = el cliente dejó la compañía este trimestre. 0 = el cliente permaneció en la compañía. Relacionado directamente con *Churn Label*.
# * **Churn Score**: Un valor entre 0 y 100 calculado usando la herramienta predictiva IBM SPSS Modeler. El modelo incorpora múltiples factores conocidos por causar cancelaciones. Cuanto más alto el puntaje, mayor la probabilidad de que el cliente se dé de baja.
# * **CLTV**: *Customer Lifetime Value* (Valor de vida del cliente). Se calcula un CLTV estimado usando fórmulas corporativas y datos existentes. Cuanto mayor el valor, más valioso es el cliente. Los clientes de alto valor deben ser monitoreados para evitar cancelaciones.
# * **Churn Reason**: Razón específica por la cual el cliente dejó la compañía. Relacionado directamente con *Churn Category*.

# %% [markdown]
# # 1.Librerias

# %%
# Tratamiento de datos
# -----------------------------------------------------------------------
import pandas as pd #manejo de estructura de datos tabulares

# Visualización de datos
# -----------------------------------------------------------------------
import matplotlib.pyplot as plt
import seaborn as sns


# importamos los warnings
# -----------------------------------------------------------------------
import warnings
warnings.filterwarnings('ignore')

# importamos configuracion de pandas
# -----------------------------------------------------------------------
pd.options.display.max_columns = None

# %% [markdown]
# # 2.Carga de datos

# %%
df = pd.read_excel("../data/raw/Telco_customer_churn.xlsx")
df
# Out:
#       CustomerID  Count        Country       State         City  Zip Code  \
# 0     3668-QPYBK    1.0  United States  California  Los Angeles   90003.0
# 1     9237-HQITU    1.0  United States  California  Los Angeles   90005.0
# 2     9305-CDSKC    1.0  United States  California  Los Angeles   90006.0
# 3     7892-POOKP    1.0  United States  California  Los Angeles   90010.0
# 4     0280-XJGEX    1.0  United States  California  Los Angeles   90015.0
# ...          ...    ...            ...         ...          ...       ...
# 7038  5666-MBJPT    1.0  United States  California  Bakersfield   93304.0
# 7039  2368-GAKKQ    1.0  United States  California       Sylmar   91342.0
# 7040  4922-CVPDX    1.0  United States  California  Westminster   92683.0
# 7041  6734-GMPVK    1.0  United States  California  Santa Maria   93454.0
# 7042  3898-BSJYF    1.0  United States  California      Herlong   96113.0
#
#                     Lat Long   Latitude   Longitude  Gender Senior Citizen  \
# 0     33.964131, -118.272783  33.964131 -118.272783    Male             No
# 1      34.059281, -118.30742  34.059281 -118.307420  Female             No
# 2     34.048013, -118.293953  34.048013 -118.293953  Female             No
# 3     34.062125, -118.315709  34.062125 -118.315709  Female             No
# 4     34.039224, -118.266293  34.039224 -118.266293    Male            NaN
# ...                      ...        ...         ...     ...            ...
# 7038  35.339796, -119.023552  35.339796 -119.023552    Male             No
# 7039  34.321621, -118.399841  34.321621 -118.399841  Female             No
# 7040  33.752591, -117.993661  33.752591 -117.993661  Female             No
# 7041  34.943523, -120.256729  34.943523 -120.256729    Male             No
# 7042   40.198234, -120.18089  40.198234 -120.180890  Female             No
#
#      Partner Dependents  Tenure Months Phone Service Multiple Lines  \
# 0         No         No            2.0           Yes             No
# 1         No        Yes            2.0           Yes             No
# 2         No        Yes            8.0           Yes            Yes
# 3        Yes        Yes           28.0           Yes            Yes
# 4         No        Yes           49.0           Yes            Yes
# ...      ...        ...            ...           ...            ...
# 7038      No         No           65.0           Yes            Yes
# 7039      No         No           70.0           Yes            Yes
# 7040     Yes         No           26.0           Yes             No
# 7041      No         No            5.0           Yes            Yes
# 7042      No        Yes           10.0           Yes            Yes
#
#      Internet Service      Online Security        Online Backup  \
# 0                 DSL                  Yes                  Yes
# 1         Fiber optic                   No                   No
# 2         Fiber optic                   No                   No
# 3         Fiber optic                   No                   No
# 4         Fiber optic                   No                  Yes
# ...               ...                  ...                  ...
# 7038               No  No internet service  No internet service
# 7039      Fiber optic                  Yes                  Yes
# 7040              DSL                   No                  Yes
# 7041      Fiber optic                   No                  Yes
# 7042              DSL                  Yes                   No
#
#         Device Protection         Tech Support         Streaming TV  \
# 0                      No                   No                   No
# 1                      No                   No                   No
# 2                     Yes                   No                  Yes
# 3                     Yes                  Yes                  Yes
# 4                     Yes                   No                  Yes
# ...                   ...                  ...                  ...
# 7038  No internet service  No internet service  No internet service
# 7039                  Yes                  Yes                  Yes
# 7040                  Yes                   No                  Yes
# 7041                  Yes                   No                  Yes
# 7042                  Yes                  Yes                   No
#
#          Streaming Movies        Contract Paperless Billing  \
# 0                      No  Month-to-month               Yes
# 1                      No  Month-to-month               Yes
# 2                     Yes  Month-to-month               Yes
# 3                     Yes  Month-to-month               Yes
# 4                     Yes  Month-to-month               Yes
# ...                   ...             ...               ...
# 7038  No internet service        Two year               Yes
# 7039                  Yes        Two year               Yes
# 7040                  Yes        Two year               Yes
# 7041                  Yes  Month-to-month                No
# 7042                  Yes        One year                No
#
#                  Payment Method  Monthly Charges Total Charges Churn Label  \
# 0                  Mailed check            53.85        108.15         Yes
# 1              Electronic check            70.70        151.65         Yes
# 2              Electronic check            99.65         820.5         Yes
# 3              Electronic check           104.80       3046.05         Yes
# 4     Bank transfer (automatic)           103.70        5036.3         Yes
# ...                         ...              ...           ...         ...
# 7038  Bank transfer (automatic)            25.10          1725          No
# 7039  Bank transfer (automatic)           113.65       7939.25          No
# 7040    Credit card (automatic)            73.50        1905.7          No
# 7041           Electronic check           105.30         550.6          No
# 7042    Credit card (automatic)            73.55         693.3          No
#
#       Churn Value  Churn Score    CLTV                   Churn Reason
# 0             1.0         86.0  3239.0   Competitor made better offer
# 1             1.0         67.0  2701.0                          Moved
# 2             1.0         86.0  5372.0                          Moved
# 3             1.0         84.0  5003.0                          Moved
# 4             1.0         89.0  5340.0  Competitor had better devices
# ...           ...          ...     ...                            ...
# 7038          0.0         46.0  5449.0                            NaN
# 7039          0.0         75.0  6424.0                            NaN
# 7040          0.0         67.0  3596.0                            NaN
# 7041          0.0         66.0  4024.0                            NaN
# 7042          0.0         29.0  4434.0                            NaN
#
# [7043 rows x 33 columns]

# %% [markdown]
# # 3.Exploración inicial de datos
#
# ## 3.1. Nulos y tipos de datos

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 33 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CustomerID         7007 non-null   object
#  1   Count              6985 non-null   float64
#  2   Country            6981 non-null   object
#  3   State              7002 non-null   object
#  4   City               7026 non-null   object
#  5   Zip Code           7037 non-null   float64
#  6   Lat Long           6995 non-null   object
#  7   Latitude           7032 non-null   float64
#  8   Longitude          7021 non-null   float64
#  9   Gender             7039 non-null   object
#  10  Senior Citizen     7006 non-null   object
#  11  Partner            6999 non-null   object
#  12  Dependents         6984 non-null   object
#  13  Tenure Months      7042 non-null   float64
#  14  Phone Service      7027 non-null   object
#  15  Multiple Lines     6996 non-null   object
#  16  Internet Service   7017 non-null   object
#  17  Online Security    7042 non-null   object
#  18  Online Backup      7023 non-null   object
#  19  Device Protection  6993 non-null   object
#  20  Tech Support       6996 non-null   object
#  21  Streaming TV       7040 non-null   object
#  22  Streaming Movies   6997 non-null   object
#  23  Contract           6984 non-null   object
#  24  Paperless Billing  7031 non-null   object
#  25  Payment Method     7040 non-null   object
#  26  Monthly Charges    7012 non-null   float64
#  27  Total Charges      6993 non-null   object
#  28  Churn Label        7028 non-null   object
#  29  Churn Value        6991 non-null   float64
#  30  Churn Score        7038 non-null   float64
#  31  CLTV               7033 non-null   float64
#  32  Churn Reason       1849 non-null   object
# dtypes: float64(9), object(24)
# memory usage: 1.8+ MB

# %% [markdown]
# Perfecto, ya tenemos un resumen claro y al grano del DataFrame: cuántas filas hay, cuántas columnas, sus nombres, qué tipo de dato tiene cada una, cuántos valores no nulos existen y hasta cuánta memoria ocupa.
#
# Saber cuántos valores no nulos tenemos es clave para analizar los datos y detectar posibles líos, como valores que faltan o que no cuadran. Eso sí, si en lugar de fijarnos en los no nulos miramos directamente los nulos, el concepto resulta más sencillo de entender.

# %%
# creamos un dataframe con las columnas que necesitamos
df_resume = pd.DataFrame(columns=["count", "null", "null_%", "dtype", "unique"])

dict_resume = {}
for i in df.columns:
    dict_resume["count"] = df[i].count()
    dict_resume["null"] = df[i].isnull().sum()
    dict_resume["null_%"] = round(df[i].isnull().sum()/len(df),2)
    dict_resume["dtype"] = df[i].dtype
    dict_resume["unique"] = df[i].nunique()
    df_aux = pd.DataFrame(dict_resume, index=[i])
    df_resume = pd.concat([df_resume, df_aux], axis=0)

df_resume
# Out:
#                   count  null  null_%    dtype unique
# CustomerID         7007    36    0.01   object   7007
# Count              6985    58    0.01  float64      1
# Country            6981    62    0.01   object      1
# State              7002    41    0.01   object      1
# City               7026    17    0.00   object   1129
# Zip Code           7037     6    0.00  float64   1652
# Lat Long           6995    48    0.01   object   1652
# Latitude           7032    11    0.00  float64   1652
# Longitude          7021    22    0.00  float64   1651
# Gender             7039     4    0.00   object      2
# Senior Citizen     7006    37    0.01   object      2
# Partner            6999    44    0.01   object      2
# Dependents         6984    59    0.01   object      2
# Tenure Months      7042     1    0.00  float64     73
# Phone Service      7027    16    0.00   object      2
# Multiple Lines     6996    47    0.01   object      3
# Internet Service   7017    26    0.00   object      3
# Online Security    7042     1    0.00   object      3
# Online Backup      7023    20    0.00   object      3
# Device Protection  6993    50    0.01   object      3
# Tech Support       6996    47    0.01   object      3
# Streaming TV       7040     3    0.00   object      3
# Streaming Movies   6997    46    0.01   object      3
# Contract           6984    59    0.01   object      3
# Paperless Billing  7031    12    0.00   object      2
# Payment Method     7040     3    0.00   object      4
# Monthly Charges    7012    31    0.00  float64   1581
# Total Charges      6993    50    0.01   object   6486
# Churn Label        7028    15    0.00   object      2
# Churn Value        6991    52    0.01  float64      2
# Churn Score        7038     5    0.00  float64     85
# CLTV               7033    10    0.00  float64   3436
# Churn Reason       1849  5194    0.74   object     20

# %%
# lo pasamos a funcion
def data_resume(df):
    """
    Devuelve un resumen de los datos del dataframe con el recuento de valores, valores nulos, porcentaje de valores nulos, tipo de dato y número de valores únicos por columna. 

    Args:
        df (pd.DataFrame): dataframe a resumir.

    Returns:
        pd.DataFrame: resumen de los datos del dataframe.
    """
    df_resume = pd.DataFrame(columns=["count", "null", "null_%", "dtype", "unique"])
    dict_resume = {}
    for i in df.columns:
        dict_resume["count"] = df[i].count()
        dict_resume["null"] = df[i].isnull().sum()
        dict_resume["null_%"] = round(df[i].isnull().sum()/len(df),2)
        dict_resume["dtype"] = df[i].dtype
        dict_resume["unique"] = df[i].nunique()
        df_aux = pd.DataFrame(dict_resume, index=[i])
        df_resume = pd.concat([df_resume, df_aux], axis=0)
    return df_resume.sort_values(by="null_%", ascending=False)

# %%
data_resume(df)
# Out:
#                   count  null  null_%    dtype unique
# Churn Reason       1849  5194    0.74   object     20
# Partner            6999    44    0.01   object      2
# Churn Value        6991    52    0.01  float64      2
# Total Charges      6993    50    0.01   object   6486
# Contract           6984    59    0.01   object      3
# Streaming Movies   6997    46    0.01   object      3
# Tech Support       6996    47    0.01   object      3
# Device Protection  6993    50    0.01   object      3
# Count              6985    58    0.01  float64      1
# Multiple Lines     6996    47    0.01   object      3
# Dependents         6984    59    0.01   object      2
# CustomerID         7007    36    0.01   object   7007
# Senior Citizen     7006    37    0.01   object      2
# Country            6981    62    0.01   object      1
# State              7002    41    0.01   object      1
# Lat Long           6995    48    0.01   object   1652
# City               7026    17    0.00   object   1129
# CLTV               7033    10    0.00  float64   3436
# Churn Score        7038     5    0.00  float64     85
# Churn Label        7028    15    0.00   object      2
# Monthly Charges    7012    31    0.00  float64   1581
# Payment Method     7040     3    0.00   object      4
# Paperless Billing  7031    12    0.00   object      2
# Zip Code           7037     6    0.00  float64   1652
# Tenure Months      7042     1    0.00  float64     73
# Streaming TV       7040     3    0.00   object      3
# Latitude           7032    11    0.00  float64   1652
# Online Backup      7023    20    0.00   object      3
# Online Security    7042     1    0.00   object      3
# Longitude          7021    22    0.00  float64   1651
# Gender             7039     4    0.00   object      2
# Phone Service      7027    16    0.00   object      2
# Internet Service   7017    26    0.00   object      3

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(df.isnull(), cbar=True, yticklabels=False, 
            cmap='viridis', annot=False)
plt.title('Valores Nulos en el Dataset')
plt.show()

# %%
# lo pasamos a funcion
def plot_nulos(df):
    plt.figure(figsize=(10, 6))
    sns.heatmap(df.isnull(), cbar=True, yticklabels=False, 
                cmap='viridis', annot=False)
    plt.title('Valores Nulos en el Dataset')
    plt.show()


plot_nulos(df)

# %% [markdown]
# ⚠️ Notas:
#
# Observamos que el tipo de datos de ciertas variables/columnas no tienen el tipo de dato correcto. Cambiamos el tipo de dato de las columnas `Count` , `Tenure Months` `Churn Value` y `Churn Score` a `int64` .
# Asi mismo los datos de las columnas `Latitude` y `Longitude` deberian ser de tipo geoespacial o generar un geopunto para su posterior analisis.
#
# Presencia de nulos que deberan de ser tratados antes de realizar cualquier tipo de analisis.
#
# ## 3.2. Duplicados

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Parece que no hay duplicados pero como estamos ante un dataset de churn, es posible que haya duplicados en el dataset de clientes.

# %%
df["CustomerID"].duplicated().sum()
# Out:
# 35

# %%
df[df["CustomerID"].duplicated()]
# Out:
#      CustomerID  Count        Country       State                City  \
# 300         NaN    1.0  United States  California               Ukiah
# 528         NaN    1.0  United States  California       Newport Coast
# 667         NaN    1.0  United States  California               Avery
# 803         NaN    1.0  United States  California         Los Angeles
# 810         NaN    1.0  United States  California            Lawndale
# 907         NaN    1.0  United States  California         Victorville
# 1313        NaN    1.0  United States  California           Silverado
# 1335        NaN    1.0  United States  California        Buttonwillow
# 1574        NaN    1.0  United States  California         Sierra City
# 1647        NaN    1.0  United States  California           La Puente
# 1721        NaN    1.0  United States  California         Los Angeles
# 1989        NaN    1.0  United States  California          Fort Irwin
# 2052        NaN    1.0  United States  California              Irvine
# 2100        NaN    1.0  United States  California              Orange
# 2353        NaN    1.0  United States  California             Fremont
# 2362        NaN    1.0  United States  California              Oakley
# 2673        NaN    1.0  United States  California          Sacramento
# 2987        NaN    1.0  United States  California              Pomona
# 3777        NaN    1.0  United States  California          Sacramento
# 3801        NaN    1.0  United States  California             Dobbins
# 4280        NaN    1.0  United States  California             Anaheim
# 4404        NaN    1.0  United States  California              Keeler
# 4568        NaN    1.0  United States  California             Vallejo
# 4635        NaN    1.0  United States  California         Santa Clara
# 4749        NaN    1.0  United States  California            Lakeport
# 4764        NaN    1.0  United States  California          Sebastopol
# 4944        NaN    1.0  United States  California          Cottonwood
# 5221        NaN    1.0  United States  California  Cardiff By The Sea
# 4280                  Yes                   No                  Yes
# 4404                   No                   No                   No
# 4568                  Yes                   No                  Yes
# 4635                  Yes                  Yes                   No
# 4749                  Yes                   No                   No
# 4764                   No                  Yes                   No
# 4944                  Yes                   No                  Yes
# 5221                   No                   No                   No
# 5320                   No                   No                  Yes
# 5321                   No                  Yes                   No
# 5732                  Yes                   No                   No
# 5854                   No                  Yes                   No
# 5872                  NaN                  Yes                  Yes
# 6093                   No                   No                  Yes
# 6285  No internet service  No internet service  No internet service
#
#              Streaming TV     Streaming Movies        Contract  \
# 300                    No                   No  Month-to-month
# 528                   Yes                  Yes        One year
# 667                    No                   No        One year
# 803                   Yes                  Yes  Month-to-month
# 810                   Yes                  Yes  Month-to-month
# 907                   Yes                  Yes  Month-to-month
# 1313                   No                   No  Month-to-month
# 1335                  Yes                   No  Month-to-month
# 1574                   No                   No  Month-to-month
# 1647                  Yes                  Yes  Month-to-month
# 1721                  Yes                  Yes        Two year
# 1989  No internet service  No internet service        One year
# 2052  No internet service  No internet service        Two year
# 2100                   No                  Yes  Month-to-month
# 2353                   No                  Yes        Two year
# 2362  No internet service  No internet service        Two year
# 2673                   No                  Yes        One year
# 2987                  Yes                   No        Two year
# 3777                  Yes                  Yes        One year
# 3801  No internet service  No internet service  Month-to-month
# 4280                   No                   No        Two year
# 4404                   No                   No  Month-to-month
# 4568                  Yes                  Yes  Month-to-month
# 4635                   No                  Yes  Month-to-month
# 4749                   No                   No  Month-to-month
# 4764                  Yes                   No        One year
# 4944                   No                   No        Two year
# 5221                  Yes                  Yes  Month-to-month
# 5320                  Yes                  Yes        Two year
# 5321                   No                   No  Month-to-month
# 5732                  Yes                   No  Month-to-month
# 5854                  Yes                   No        Two year
# 5872                   No                   No        Two year
# 6093                  Yes                   No        One year
# 6285  No internet service  No internet service        Two year
#
#      Paperless Billing             Payment Method  Monthly Charges  \
# 300                 No           Electronic check            44.75
# 528                Yes           Electronic check           111.30
# 667                 No  Bank transfer (automatic)            24.10
# 803                Yes           Electronic check           103.90
# 810                Yes           Electronic check            96.05
# 907                Yes           Electronic check           101.40
# 1313                No    Credit card (automatic)            51.75
# 1335               Yes               Mailed check            94.85
# 1574               Yes           Electronic check            70.85
# 1647               Yes           Electronic check            95.45
# 1721               Yes    Credit card (automatic)            79.75
# 1989                No  Bank transfer (automatic)            20.85
# 2052               Yes    Credit card (automatic)            21.10
# 2100                No               Mailed check            65.55
# 2353                No  Bank transfer (automatic)            73.25
# 2362                No               Mailed check            19.60
# 2673               Yes  Bank transfer (automatic)            92.30
# 2987               Yes  Bank transfer (automatic)            72.10
# 3777               Yes    Credit card (automatic)           106.00
# 3801                No               Mailed check            18.95
# 4280                No  Bank transfer (automatic)            65.15
# 4404                No  Bank transfer (automatic)            50.10
# 4568               Yes    Credit card (automatic)           110.10
# 4635               Yes           Electronic check            89.55
# 4749               Yes           Electronic check            81.15
# 4764               Yes    Credit card (automatic)            89.60
# 4944                No               Mailed check            40.55
# 5221                No    Credit card (automatic)            66.40
# 5320               Yes  Bank transfer (automatic)            75.20
# 5321               Yes    Credit card (automatic)            84.75
# 5732               Yes           Electronic check            87.10
# 5854               Yes           Electronic check            89.55
# 5872                No  Bank transfer (automatic)            69.40
# 6093                No  Bank transfer (automatic)            69.05
# 6285               Yes               Mailed check            18.70
#
#      Total Charges Churn Label  Churn Value  Churn Score    CLTV  \
# 300         270.95         Yes          1.0         78.0  2087.0
# 528         7482.1         Yes          1.0         85.0  4146.0
# 667          259.8         Yes          1.0         82.0  3195.0
# 803         2254.2         Yes          1.0         91.0  3769.0
# 810         1148.1         Yes          1.0         89.0  2577.0
# 907         3496.3         Yes          1.0         92.0     NaN
# 1313         201.1         Yes          1.0         83.0  3865.0
# 1335         890.6         Yes          1.0         72.0  3016.0
# 1574         70.85         Yes          1.0         72.0  2874.0
# 1647         95.45         Yes          1.0         71.0  5962.0
# 1721        4217.8          No          0.0         49.0  4142.0
# 1989        720.05          No          0.0         78.0  5744.0
# 2052        490.65          No          0.0         46.0  4368.0
# 2100         237.2          No          0.0         46.0  5707.0
# 2353        4054.2          No          0.0         26.0  4011.0
# 2362        808.95          No          0.0         34.0  2630.0
# 2673       5731.45          No          0.0         58.0  6468.0
# 2987       4194.85          No          0.0         52.0  6225.0
# 3777        4532.3          No          0.0         76.0  3528.0
# 3801        110.15          No          0.0         68.0  5920.0
# 4280       4681.75          No          0.0         69.0  4384.0
# 4404         709.5          No          0.0         25.0  2331.0
# 4568        4469.1          No          0.0         39.0  2283.0
# 4635       2187.15          No          0.0         41.0  2007.0
# 4749       2640.55          No          0.0         25.0  3031.0
# 4764          1633          No          0.0         36.0  2269.0
# 4944        590.35          No          0.0         27.0  2898.0
# 5221        831.75          No          0.0         43.0  3660.0
# 5320       3901.25          No          0.0         59.0  4708.0
# 5321        2613.4          No          0.0         35.0  3727.0
# 5732         713.6          No          0.0         65.0  3950.0
# 5854        5231.2          No          0.0         74.0  5874.0
# 5872        4237.5          No          0.0         67.0  6469.0
# 6093       1958.45          No          0.0         33.0  4459.0
# 6285        383.65          No          0.0         42.0  2289.0
#
#                          Churn Reason
# 300               Network reliability
# 528        Attitude of support person
# 667      Competitor offered more data
# 803         Limited range of services
# 810   Lack of self-service on Website
# 907      Competitor offered more data
# 1313    Competitor had better devices
# 1335                       Don't know
# 1574              Network reliability
# 1647       Attitude of support person
# 1721                              NaN
# 1989                              NaN
# 2052                              NaN
# 2100                              NaN
# 2353                              NaN
# 2362                              NaN
# 2673                              NaN
# 2987                              NaN
# 3777                              NaN
# 3801                              NaN
# 4280                              NaN
# 4404                              NaN
# 4568                              NaN
# 4635                              NaN
# 4749                              NaN
# 4764                              NaN
# 4944                              NaN
# 5221                              NaN
# 5320                              NaN
# 5321                              NaN
# 5732                              NaN
# 5854                              NaN
# 5872                              NaN
# 6093                              NaN
# 6285                              NaN

# %% [markdown]
# #

# %% [markdown]
# ⚠️ Nota: Parece que hay duplicados en los clientes. En otras circunstancias podria ser problematico pero al tener una columna `Count`vemos que estos no se repiten por lo que podriamos realizar un analisis sin myor problema.
#
#
# # Next Steps
#
# - Editar el nombre de las columnas para facilitar la manipulacion de datos
# - Eliminar columnas redundantes
# - Ajustar los tipos de datos
# - Tratar los valores nulos
